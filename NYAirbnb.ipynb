# %% [markdown]
# <b> Importing Libraries </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b> Reading the dataset </b>

# %%
airbnb=pd.read_csv('dataset.csv')
airbnb.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# <b> Analysing our data </b>

# %%
airbnb.shape
# Out:
# (48895, 16)

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48879 non-null object
# host_id                           48895 non-null int64
# host_name                         48874 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# ...

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# <b> Checking for any missing values </b>

# %%
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# <b> Dropping unnecessary columns </b>

# %%
airbnb.drop(['id','name','host_name','last_review'], axis=1, inplace=True)

# %% [markdown]
# <b> Replacing the missing values in 'reviews per month' by zero </b>

# %%
airbnb.fillna({'reviews_per_month':0}, inplace=True)

# %%
airbnb.isnull().sum()
# Out:
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# <b> Further examining our data </b>

# %%
airbnb.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
airbnb.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
airbnb.neighbourhood.unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
airbnb.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
top_host=airbnb.host_id.value_counts().head(10)
top_host
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 12243051      96
# 16098958      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %% [markdown]
# <b> Visualizing listings of top 10 hosts </b>

# %%
hostplot=top_host.plot(kind='bar')
hostplot.set_title('Hosts with the most listings in NYC')
hostplot.set_ylabel('Count of listings')
hostplot.set_xlabel('Host IDs')
hostplot.set_xticklabels(hostplot.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '219517861'),
#  Text(0, 0, '107434423'),
#  Text(0, 0, '30283594'),
#  Text(0, 0, '137358866'),
#  Text(0, 0, '12243051'),
#  Text(0, 0, '16098958'),
#  Text(0, 0, '61391963'),
#  Text(0, 0, '22541573'),
#  Text(0, 0, '200380610'),
#  Text(0, 0, '7503643')]

# %% [markdown]
# <b> Plotting Neighbourhood Groups as countplot </b>

# %%
sns.countplot(airbnb['neighbourhood_group'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# There are maximum number of listings in Manhattan neighbourhood and minimum number of listings in Staten Island.

# %% [markdown]
# <b> Count of types of rooms available </b>

# %%
sns.countplot(airbnb['room_type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type of room')
# Out:
# Text(0.5, 1.0, 'Type of room')

# %% [markdown]
# Hence, a shared room is least preferred and available.

# %% [markdown]
# <b> Neighbourhood Group and Room type </b>

# %%
sns.countplot(data=airbnb,x='neighbourhood_group', hue='room_type')
fig = plt.gcf()
fig.set_size_inches(10,10)

# %% [markdown]
# We have maximum number of listings for Entire home/apartment in Manhattan.

# %% [markdown]
# <b> Geographical plot of various neighbourhood groups </b>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(airbnb.longitude,airbnb.latitude,hue=airbnb.neighbourhood_group)

# %% [markdown]
# <b> Vizualising room types available on a geographical map </b>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(airbnb.longitude,airbnb.latitude,hue=airbnb.room_type)

# %% [markdown]
# <b> Room availibility out of 365 days </b>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(airbnb.longitude,airbnb.latitude,hue=airbnb.availability_365)

# %% [markdown]
# <b> Relationship between no. of reviews per month and the price </b>

# %%
var = 'reviews_per_month'
data = pd.concat([airbnb['price'], airbnb[var]], axis=1)
data.plot.scatter(x=var, y='price' ,ylim=(0,10000))

# %% [markdown]
# As we can see, there is no solid relationship between no. of reviews per month and the price.

# %% [markdown]
# <b> Now, we shall visualize the average prices of listings by top 10 hosts. </b>

# %%
top_list=top_host.index
top_list
# Out:
# Int64Index([219517861, 107434423,  30283594, 137358866,  12243051,  16098958,
#              61391963,  22541573, 200380610,   7503643],
#            dtype='int64')

# %% [markdown]
# Creating another dataframe so that it'll be easier to analyze

# %%
top_df= airbnb[['host_id', 'price']]
top_df.head()
# Out:
#    host_id  price
# 0     2787    149
# 1     2845    225
# 2     4632    150
# 3     4869     89
# 4     7192     80

# %%
top_df.shape
# Out:
# (48895, 2)

# %%
top_df = top_df[top_df['host_id'].isin(top_list)]

# %%
top_df.shape
# Out:
# (1270, 2)

# %%
top_df['host_id'].value_counts()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# 12243051      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %% [markdown]
# <b> Creating a pivot table for aggregation </b>

# %%
table = pd.pivot_table(top_df,index=['host_id'],values=['price'], aggfunc='mean')
table
# Out:
#                 price
# host_id
# 7503643    149.192308
# 12243051   213.031250
# 16098958   208.958333
# 22541573   215.436782
# 30283594   277.528926
# 61391963   146.241758
# 107434423  303.150862
# 137358866   43.825243
# 200380610  290.230769
# 219517861  253.195719

# %%
table.plot(kind='barh', title='Mean Price quoted by Top 10 hosts', xlim=(10,500), legend=False)

# %% [markdown]
# From the plot above, we can understand that host with Host ID 107434423 having 232 property listings has maximum average price of 303.150862 for his properties. And the minimum average price is given by host with Host ID 137358866 at 43.825243.
